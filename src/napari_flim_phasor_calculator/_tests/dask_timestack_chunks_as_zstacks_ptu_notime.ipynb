# %%
import dask.array as da
import dask
from pathlib import Path
import napari
from natsort import natsorted
import numpy as np
from napari_flim_phasor_calculator._reader import get_current_tz, read_ptu_data_2D, read_ptu_3D_data

# %% [markdown]
# Define read 2d and 3d functions

# %%
folder_path = r"C:\Users\mazo260d\Desktop\Conni_BiA_PoL\stack_smaller"

folder_path = Path(folder_path)

# %% [markdown]
# Get max slice shape

# %%
# Read all slices to get slice max shape and dtype (not ideal but for now it is OK)
slice_shape_list = []
for file_path in folder_path.iterdir():
    if file_path.suffix == '.ptu':
        image_2D = read_ptu_data_2D(file_path)
        slice_shape_list.append(image_2D.shape)
slice_max_shape = max(slice_shape_list)
print('last_slice_shape = ', image_2D.shape,'image_dtype = ', image_2D.dtype)
print('max_slice_shape = ', slice_max_shape)
# Out:
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# last_slice_shape =  (2, 134, 256, 256) image_dtype =  uint16
# max_slice_shape =  (2, 136, 256, 256)

# %% [markdown]
# Get max z slices and max t timepoints from filepaths

# %%
file_paths = [file_path for file_path in folder_path.iterdir() if file_path.suffix == '.ptu']

# Get max z slices by reading all file names
def get_max_zslices(file_paths):
    max_z = max([get_current_tz(file_path) for file_path in file_paths if file_path.suffix == '.ptu'])[1]
    if max_z is None:
        return 1
    return max_z
def get_max_time(file_paths):
    max_time = max([get_current_tz(file_path) for file_path in file_paths if file_path.suffix == '.ptu'])[0]
    if max_time is None:
        return 1
    return max_time

max_z = get_max_zslices(file_paths)
print('max_z slices = ', max_z)
max_t = get_max_time(file_paths)
print('max_time = ', max_t)
# Out:
# max_z slices =  43
# max_time =  1

# %% [markdown]
# Get stack max shape

# %%
image_stack_shape = (*slice_max_shape[:-2], max_z, *slice_max_shape[-2:])
image_stack_shape
# Out:
# (2, 136, 43, 256, 256)

# %% [markdown]
# Make dask array

# %%
t_path_list = []
z_path_list = []
file_paths = natsorted(file_paths)
previous_t = 1
for file_path in file_paths:
    if file_path.suffix == '.ptu':
        current_t, current_z = get_current_tz(file_path)
        print(current_t, current_z)
        if current_t is not None:
            if current_t > previous_t:
                t_path_list.append(z_path_list)
                z_path_list = []
                previous_t = current_t
            z_path_list.append(file_path)

# If no timepoints, z+path_list is file_paths
if current_t is None:
    z_path_list = file_paths

# Append last timepoint
t_path_list.append(z_path_list)
# Out:
# None 1
# None 2
# None 3
# None 4
# None 5
# None 6
# None 7
# None 8
# None 9
# None 10
# None 11
# None 12
# None 13
# None 14
# None 15
# None 16
# None 17
# None 18
# None 19
# None 20
# None 21
# None 22
# None 23
# None 24
# None 25
# None 26
# None 27
# None 28
# None 29
# None 30
# None 31
# None 32
# None 33
# None 34
# None 35
# None 36
# None 37
# None 38
# None 39
# None 40
# None 41
# None 42
# None 43

# %%
z_path_list
# Out:
# [WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z1.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z2.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z3.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z4.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z5.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z6.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z7.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z8.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z9.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z10.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z11.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z12.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z13.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z14.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z15.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z16.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z17.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z18.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z19.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z20.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z21.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z22.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z23.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z24.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z25.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z26.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z27.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z28.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z29.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z30.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z31.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z32.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z33.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z34.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z35.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z36.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z37.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z38.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z39.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z40.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z41.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z42.ptu'),
#  WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z43.ptu')]

# %%
for z_path_list in t_path_list:
    print(z_path_list)
# Out:
# [WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z1.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z2.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z3.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z4.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z5.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z6.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z7.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z8.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z9.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z10.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z11.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z12.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z13.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z14.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z15.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z16.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z17.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z18.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z19.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z20.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z21.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z22.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z23.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z24.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z25.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z26.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z27.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z28.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z29.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z30.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z31.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z32.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z33.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z34.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z35.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z36.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z37.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z38.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z39.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA_PoL/stack_smaller/embryo_43pl_2ch_3tps_z40.ptu'), WindowsPath('C:/Users/mazo260d/Desktop/Conni_BiA ...

# %%
read_tif_data_3D_delayed = dask.delayed(read_ptu_3D_data, pure=True)

lazy_images = [read_tif_data_3D_delayed(z_path_list, image_slice_shape=slice_max_shape) for z_path_list in t_path_list]

arrays = [da.from_delayed(lazy_image,           # Construct a small Dask array
                          dtype=image_2D.dtype,   # for every lazy value
                          shape=image_stack_shape)
          for lazy_image in lazy_images]

stack = da.stack(arrays, axis=0)                # Stack all small Dask arrays into one
print('stack shape and chunks = ', stack.shape, '\n', stack.chunks)
# Out:
# stack shape and chunks =  (1, 2, 136, 43, 256, 256)
#  ((1,), (2,), (136,), (43,), (256,), (256,))

# %%
stack
# Out:
# dask.array<stack, shape=(1, 2, 136, 43, 256, 256), dtype=uint16, chunksize=(1, 2, 136, 43, 256, 256), chunktype=numpy.ndarray>

# %%
viewer = napari.Viewer()
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 3258x2028-6+3 (frame: 3290x2116-22-69) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 5435x2108-1+30 (frame: 5467x2196-17-42) margins: 16, 72, 16, 16 minimum size: 374x554 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1154,1750 maxtrack=0,0)

# %%
viewer.add_image(stack, channel_axis=1)
# Out:
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
#
# TCSPC Hardware: PicoHarpT3
# Raw Data has been Read!
# [<Image layer 'Image' at 0x202b0d7ae20>,
#  <Image layer 'Image [1]' at 0x202af5eeee0>]
