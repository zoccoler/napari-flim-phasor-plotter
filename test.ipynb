# %%
from skimage import morphology
import napari
from napari.utils import nbscreenshot
import numpy as np
import napari_flim_phasor_plotter as flim_plot
import napari_clusters_plotter as ncp
from skimage.measure import label, regionprops_table

# %%
viewer = napari.Viewer()
list_layerdatatuple = flim_plot._sample_data.load_seminal_receptacle_image()
image_layer = viewer.add_image(list_layerdatatuple[0][0], **list_layerdatatuple[0][1])
nbscreenshot(viewer)

# %%
flim_plot._widget.make_flim_phasor_plot
# Out:
# MagicFactory(function=<function make_flim_phasor_plot at 0x7fd104540310>, param_options={'laser_frequency': {'step': 0.001, 'tooltip': 'If loaded image has metadata, laser frequency will get automatically updated after run. Otherwise, manually insert laser frequency here.'}})

# %%
phasor_plot_widget = flim_plot._widget.make_flim_phasor_plot()

# %%
phasor_plot_widget(image_layer,
threshold = 10,
apply_median =True,
median_n = 1,
napari_viewer = viewer)

# %%
nbscreenshot(viewer)
